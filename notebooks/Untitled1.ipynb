# %%
import sys
sys.path.append('../code')
sys.path.append('../data')
sys.path
from data_processing import get_data

# %%
sys.path
# Out:
# ['/Users/ferguscurrie/Documents/Uni/Research/Implementations',
#  '/usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/ferguscurrie/Library/Python/3.9/lib/python/site-packages',
#  '/usr/local/lib/python3.9/site-packages',
#  '/usr/local/opt/python-tk@3.9/libexec',
#  '/usr/local/lib/python3.9/site-packages/IPython/extensions',
#  '/Users/ferguscurrie/.ipython',
#  '../code',
#  '../code',
#  '../code',
#  '../data',
#  '../../Implementations',
#  '../../Implementations',
#  '../code',
#  '../data']

# %%
_, y = get_data('cleveland')
y
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-8ef627a204e7> in <module>
# ----> 1 _, y = get_data('cleveland')
#       2 y
#
# ~/Documents/Uni/Research/Implementations/notebooks/../code/data_processing.py in get_data(name)
#     165
#     166 def get_data(name) -> np.array:
# --> 167     df = _load_file(name)
#     168     X, y = _to_numpy_x_y(df)
#     169     return X, y
#
# ~/Documents/Uni/Research/Implementations/notebooks/../code/data_processing.py in _load_file(name)
#     137     # about wehrre firwt file iw run from in terms f relative path
#     138     if name == 'cleveland':
# --> 139         return _cleveland_load('data/datasets/cleveland/processed.cleveland.data')
#     140     if name == 'ionosphere':
#     141         return _ionosphere_load('data/datasets/ionosphere/ionosphere.data')
#
# ...
